# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'serif'

# %%
featured_data = pd.read_csv('extracted_features_candidate_data_ver1.csv')
featured_data.head()
# Out:
#    id                                          job_title  \
# 0   1  2019 C.T. Bauer College of Business Graduate (...
# 1   2  Native English Teacher at EPIK (English Progra...
# 2   3              Aspiring Human Resources Professional
# 3   4             People Development Coordinator at Ryan
# 4   5    Advisory Board Member at Celal Bayar University
#
#                               location connection  similarity_scores  \
# 0                       Houston, Texas         85           0.084313
# 1                               Kanada      500+            0.138683
# 2  Raleigh-Durham, North Carolina Area         44           0.434607
# 3                        Denton, Texas      500+            0.369073
# 4                       İzmir, Türkiye      500+            0.143914
#
#                                   roberta_embeddings  \
# 0  [ 0.05727464  0.04327847 -0.08864243  0.078854...
# 1  [-0.0280511   0.02117271 -0.05655353  0.131397...
# 2  [-0.09449603  0.08710561 -0.03834165 -0.241207...
# 3  [-6.82737157e-02 -4.67730649e-02  8.82590469e-...
# 4  [-0.03519841  0.08660441 -0.00772008  0.111947...
#
#                                 job_title_lemmatized  job_title_char_count  \
# 0  2019 C.T. Bauer College Business Graduate ( Ma...                   104
# 1  native English teacher EPIK ( English Program ...                    57
# 2              Aspiring Human Resources Professional                    37
# 3                People Development Coordinator Ryan                    38
# 4       Advisory Board Member Celal Bayar University                    47
#
#    job_title_word_count  job_title_avg_word_len  ...  \
# 0                    15                6.933333  ...
# 1                     9                6.333333  ...
# 2                     4                9.250000  ...
# 3                     5                7.600000  ...
# 4                     7                6.714286  ...
#
#                      sentence_transformer_embeddings  word2vec_similarity  \
# 0  [-0.07176385  0.00226361 -0.01785826  0.031808...             0.452996
# 1  [-0.01213636  0.01905449  0.03814819  0.013521...             0.552295
# 2  [-0.03121115  0.04798941 -0.01407243  0.099423...             0.861874
# 3  [-1.06952295e-01 -2.07451340e-02 -8.79813433e-...             0.817421
# 4  [-0.09358544  0.02436637 -0.00867575 -0.002508...             0.687182
#
#    sentence_similarity  experience_score  \
# 0             0.535285               0.0
# 1             0.253609               0.0
# 2             0.877541               0.0
# 3             0.606107               0.0
# 4             0.304957               0.0
#
#                                     Glove_embeddings Glove_similarity  \
# 0  [-0.40228087  0.62138881 -0.15870494 -0.150460...         0.779651
# 1  [-4.21277778e-01  5.87644444e-01 -4.62456667e-...         0.698349
# 2  [-3.00725000e-01  3.48392500e-01 -1.41115000e-...         0.962704
# 3  [ 2.4258200e-01  3.0578460e-01 -4.9482000e-02 ...         0.759374
# 4  [-0.36904286  0.27080571 -0.27726843  0.113543...         0.611781
#
#          country            city               region connection_score
# 0  United States         Houston                Texas            0.170
# 1         Canada             NaN               Kanada            1.000
# 2  United States  Raleigh-Durham  North Carolina Area            0.088
# 3  United States          Denton                Texas            1.000
# 4        Türkiye           İzmir                  NaN            1.000
#
# [5 rows x 25 columns]

# %%
featured_data = featured_data.drop('id', axis=1)

# %%
featured_data.shape
# Out:
# (104, 24)

# %%
features_data_no_duplicates = featured_data.drop_duplicates(ignore_index=True)
features_data_no_duplicates.shape
# Out:
# (56, 24)

# %%
features_data_no_duplicates.head()
# Out:
#                                            job_title  \
# 0  2019 C.T. Bauer College of Business Graduate (...
# 1  Native English Teacher at EPIK (English Progra...
# 2              Aspiring Human Resources Professional
# 3             People Development Coordinator at Ryan
# 4    Advisory Board Member at Celal Bayar University
#
#                               location connection  similarity_scores  \
# 0                       Houston, Texas         85           0.084313
# 1                               Kanada      500+            0.138683
# 2  Raleigh-Durham, North Carolina Area         44           0.434607
# 3                        Denton, Texas      500+            0.369073
# 4                       İzmir, Türkiye      500+            0.143914
#
#                                   roberta_embeddings  \
# 0  [ 0.05727464  0.04327847 -0.08864243  0.078854...
# 1  [-0.0280511   0.02117271 -0.05655353  0.131397...
# 2  [-0.09449603  0.08710561 -0.03834165 -0.241207...
# 3  [-6.82737157e-02 -4.67730649e-02  8.82590469e-...
# 4  [-0.03519841  0.08660441 -0.00772008  0.111947...
#
#                                 job_title_lemmatized  job_title_char_count  \
# 0  2019 C.T. Bauer College Business Graduate ( Ma...                   104
# 1  native English teacher EPIK ( English Program ...                    57
# 2              Aspiring Human Resources Professional                    37
# 3                People Development Coordinator Ryan                    38
# 4       Advisory Board Member Celal Bayar University                    47
#
#    job_title_word_count  job_title_avg_word_len  keyword_char_match  ...  \
# 0                    15                6.933333            0.269231  ...
# 1                     9                6.333333            0.438596  ...
# 2                     4                9.250000            0.756757  ...
# 3                     5                7.600000            0.526316  ...
# 4                     7                6.714286            0.531915  ...
#
#                      sentence_transformer_embeddings  word2vec_similarity  \
# 0  [-0.07176385  0.00226361 -0.01785826  0.031808...             0.452996
# 1  [-0.01213636  0.01905449  0.03814819  0.013521...             0.552295
# 2  [-0.03121115  0.04798941 -0.01407243  0.099423...             0.861874
# 3  [-1.06952295e-01 -2.07451340e-02 -8.79813433e-...             0.817421
# 4  [-0.09358544  0.02436637 -0.00867575 -0.002508...             0.687182
#
#    sentence_similarity experience_score  \
# 0             0.535285              0.0
# 1             0.253609              0.0
# 2             0.877541              0.0
# 3             0.606107              0.0
# 4             0.304957              0.0
#
#                                     Glove_embeddings  Glove_similarity  \
# 0  [-0.40228087  0.62138881 -0.15870494 -0.150460...          0.779651
# 1  [-4.21277778e-01  5.87644444e-01 -4.62456667e-...          0.698349
# 2  [-3.00725000e-01  3.48392500e-01 -1.41115000e-...          0.962704
# 3  [ 2.4258200e-01  3.0578460e-01 -4.9482000e-02 ...          0.759374
# 4  [-0.36904286  0.27080571 -0.27726843  0.113543...          0.611781
#
#          country            city               region  connection_score
# 0  United States         Houston                Texas             0.170
# 1         Canada             NaN               Kanada             1.000
# 2  United States  Raleigh-Durham  North Carolina Area             0.088
# 3  United States          Denton                Texas             1.000
# 4        Türkiye           İzmir                  NaN             1.000
#
# [5 rows x 24 columns]

# %%
features_data_no_duplicates = features_data_no_duplicates.drop(columns=[
    'location',
    'connection',
    'roberta_embeddings',
    'job_title_lemmatized',
    'word2vec_embeddings',
    'sentence_transformer_embeddings',
    'Glove_embeddings'
])
features_data_no_duplicates.head()
# Out:
#                                            job_title  similarity_scores  \
# 0  2019 C.T. Bauer College of Business Graduate (...           0.084313
# 1  Native English Teacher at EPIK (English Progra...           0.138683
# 2              Aspiring Human Resources Professional           0.434607
# 3             People Development Coordinator at Ryan           0.369073
# 4    Advisory Board Member at Celal Bayar University           0.143914
#
#    job_title_char_count  job_title_word_count  job_title_avg_word_len  \
# 0                   104                    15                6.933333
# 1                    57                     9                6.333333
# 2                    37                     4                9.250000
# 3                    38                     5                7.600000
# 4                    47                     7                6.714286
#
#    keyword_char_match  seniority_score  job_title_punct_penalty  \
# 0            0.269231              0.0                 0.019231
# 1            0.438596              0.0                 0.035088
# 2            0.756757              0.0                 0.000000
# 3            0.526316              0.0                 0.000000
# 4            0.531915              0.0                 0.000000
#
#    similarity_cluster  word2vec_similarity  sentence_similarity  \
# 0                   0             0.452996             0.535285
# 1                   0             0.552295             0.253609
# 2                   1             0.861874             0.877541
# 3                   1             0.817421             0.606107
# 4                   0             0.687182             0.304957
#
#    experience_score  Glove_similarity        country            city  \
# 0               0.0          0.779651  United States         Houston
# 1               0.0          0.698349         Canada             NaN
# 2               0.0          0.962704  United States  Raleigh-Durham
# 3               0.0          0.759374  United States          Denton
# 4               0.0          0.611781        Türkiye           İzmir
#
#                 region  connection_score
# 0                Texas             0.170
# 1               Kanada             1.000
# 2  North Carolina Area             0.088
# 3                Texas             1.000
# 4                  NaN             1.000

# %%
print("Unique country count:", features_data_no_duplicates['country'].nunique())
print("Unique region count:", features_data_no_duplicates['region'].nunique())
print("Unique city count:", features_data_no_duplicates['city'].nunique())
# Out:
# Unique country count: 4
# Unique region count: 30
# Unique city count: 34

# %%
# Drop 'city' and 'region' columns
featured_data_encoded = features_data_no_duplicates.drop(columns=['city', 'region'])

# One-hot encode the 'country' categorical feature
featured_data_encoded = pd.get_dummies(featured_data_encoded, columns=['country'])

featured_data_encoded.head()
# Out:
#                                            job_title  similarity_scores  \
# 0  2019 C.T. Bauer College of Business Graduate (...           0.084313
# 1  Native English Teacher at EPIK (English Progra...           0.138683
# 2              Aspiring Human Resources Professional           0.434607
# 3             People Development Coordinator at Ryan           0.369073
# 4    Advisory Board Member at Celal Bayar University           0.143914
#
#    job_title_char_count  job_title_word_count  job_title_avg_word_len  \
# 0                   104                    15                6.933333
# 1                    57                     9                6.333333
# 2                    37                     4                9.250000
# 3                    38                     5                7.600000
# 4                    47                     7                6.714286
#
#    keyword_char_match  seniority_score  job_title_punct_penalty  \
# 0            0.269231              0.0                 0.019231
# 1            0.438596              0.0                 0.035088
# 2            0.756757              0.0                 0.000000
# 3            0.526316              0.0                 0.000000
# 4            0.531915              0.0                 0.000000
#
#    similarity_cluster  word2vec_similarity  sentence_similarity  \
# 0                   0             0.452996             0.535285
# 1                   0             0.552295             0.253609
# 2                   1             0.861874             0.877541
# 3                   1             0.817421             0.606107
# 4                   0             0.687182             0.304957
#
#    experience_score  Glove_similarity  connection_score  \
# 0               0.0          0.779651             0.170
# 1               0.0          0.698349             1.000
# 2               0.0          0.962704             0.088
# 3               0.0          0.759374             1.000
# 4               0.0          0.611781             1.000
#
#    country_Amerika Birleşik Devletleri  country_Canada  country_Türkiye  \
# 0                                False           False            False
# 1                                False            True            False
# 2                                False           False            False
# 3                                False           False            False
# 4                                False           False             True
#
#    country_United States
# 0                   True
# 1                  False
# 2                   True
# 3                   True
# 4                  False

# %%
featured_data_encoded.shape
# Out:
# (56, 18)

# %%
# Rename the 4 country columns in featured_data_encoded
country_columns = [
    'country_Amerika Birleşik Devletleri',
    'country_Canada',
    'country_Türkiye',
    'country_United States'
]
new_country_columns = ['country_1', 'country_2', 'country_3', 'country_4']

featured_data_encoded = featured_data_encoded.rename(
    columns=dict(zip(country_columns, new_country_columns))
)

featured_data_encoded.head()
# Out:
#                                            job_title  similarity_scores  \
# 0  2019 C.T. Bauer College of Business Graduate (...           0.084313
# 1  Native English Teacher at EPIK (English Progra...           0.138683
# 2              Aspiring Human Resources Professional           0.434607
# 3             People Development Coordinator at Ryan           0.369073
# 4    Advisory Board Member at Celal Bayar University           0.143914
#
#    job_title_char_count  job_title_word_count  job_title_avg_word_len  \
# 0                   104                    15                6.933333
# 1                    57                     9                6.333333
# 2                    37                     4                9.250000
# 3                    38                     5                7.600000
# 4                    47                     7                6.714286
#
#    keyword_char_match  seniority_score  job_title_punct_penalty  \
# 0            0.269231              0.0                 0.019231
# 1            0.438596              0.0                 0.035088
# 2            0.756757              0.0                 0.000000
# 3            0.526316              0.0                 0.000000
# 4            0.531915              0.0                 0.000000
#
#    similarity_cluster  word2vec_similarity  sentence_similarity  \
# 0                   0             0.452996             0.535285
# 1                   0             0.552295             0.253609
# 2                   1             0.861874             0.877541
# 3                   1             0.817421             0.606107
# 4                   0             0.687182             0.304957
#
#    experience_score  Glove_similarity  connection_score  country_1  country_2  \
# 0               0.0          0.779651             0.170      False      False
# 1               0.0          0.698349             1.000      False       True
# 2               0.0          0.962704             0.088      False      False
# 3               0.0          0.759374             1.000      False      False
# 4               0.0          0.611781             1.000      False      False
#
#    country_3  country_4
# 0      False       True
# 1      False      False
# 2      False       True
# 3      False       True
# 4       True      False

# %%
class InitialRanker:
    def __init__(self):
        self.feature_weights = {
            'similarity_scores': 0.15,
            'word2vec_similarity': 0.15,
            'sentence_transformer_similarity': 0.15,
            'Glove_similarity': 0.15,    
            'keyword_char_match': 0.1,
            'seniority_score': 0.05,
            'connection_score': 0.03,
            'country_1': 0.02,
            'country_2': 0.02,
            'country_3': 0.02,
            'country_4': 0.02,
            'experience_score':0.01,
            'job_title_punct_penalty':-0.03,
            'job_title_avg_word_len':0.02,
            'job_title_char_count': 0.02
        }
        self.scaler = StandardScaler()
    
    def rank_results(self, features_df):
        # Normalize features
        normalized_features = self.scaler.fit_transform(features_df)
        
        # Calculate weighted score
        scores = np.zeros(len(features_df))
        for i, (feature, weight) in enumerate(self.feature_weights.items()):
            scores += weight * normalized_features[:, i]
        
        # Min-max scale scores to [0, 1]
        min_score = scores.min()
        max_score = scores.max()
        if max_score > min_score:
            scores_scaled = (scores - min_score) / (max_score - min_score)
        else:
            scores_scaled = np.zeros_like(scores)
        
        # Return ranked indices and scaled scores
        ranked_indices = np.argsort(scores_scaled)[::-1]
        return ranked_indices, scores_scaled

# %%
featured_data_encoded
# Out:
#                                             job_title  similarity_scores  \
# 0   2019 C.T. Bauer College of Business Graduate (...           0.084313
# 1   Native English Teacher at EPIK (English Progra...           0.138683
# 2               Aspiring Human Resources Professional           0.434607
# 3              People Development Coordinator at Ryan           0.369073
# 4     Advisory Board Member at Celal Bayar University           0.143914
# 5                 Aspiring Human Resources Specialist           0.345871
# 6   Student at Humber College and Aspiring Human R...           0.166385
# 7                                HR Senior Specialist           0.365738
# 8   Seeking Human Resources HRIS and Generalist Po...           0.072384
# 9                       Student at Chapman University           0.142392
# 10  SVP, CHRO, Marketing & Communications, CSR Off...           0.626174
# 11  Human Resources Coordinator at InterContinenta...           0.258530
# 12              Aspiring Human Resources Professional           0.434607
# 13  Aspiring Human Resources Management student se...           0.335323
# 14              Seeking Human Resources Opportunities           0.188090
# 15  Student at Humber College and Aspiring Human R...           0.166385
# 16  Seeking Human Resources HRIS and Generalist Po...           0.072384
# 17  Experienced Retail Manager and aspiring Human ...           0.462731
# 18  Human Resources, Staffing and Recruiting Profe...           0.279908
# 19            Human Resources Specialist at Luxottica           0.292509
# 20  Director of Human Resources North America, Gro...           0.425332
# 21  Retired Army National Guard Recruiter, office ...           0.285704
# 22    Human Resources Generalist at ScottMadden, Inc.           0.510722
# 23  Business Management Major and Aspiring Human R...           0.279236
# 24  Aspiring Human Resources Manager, seeking inte...           0.328378
# 25                       Human Resources Professional           0.564406
# 26  Nortia Staffing is seeking Human Resources, Pa...           0.362404
# 27  Aspiring Human Resources Professional | Passio...           0.414139
# 28  Human Resources|\nConflict Management|\nPolici...           0.207744
# 29             Human Resources Generalist at Schwan's           0.369932
# 30  Liberal Arts Major. Aspiring Human Resources A...           0.302996
# 31           Junior MES Engineer| Information Systems           0.327936
# 32  Senior Human Resources Business Partner at Hei...           0.497335
# 33  Aspiring Human Resources Professional | An ene...           0.334932
# 34          HR Manager at Endemol Shine North America           0.434568
# 35  Human Resources professional for the world lea...           0.433419
# 36  RRP Brand Portfolio Executive at JTI (Japan To...           0.385114
# 37  Information Systems Specialist and Programmer ...           0.395373
# 38  Bachelor of Science in Biology from Victoria U...           0.176140
# 39                   Human Resources Management Major           0.333459
# 40                    Director Human Resources  at EY           0.448510
# 41  Undergraduate Research Assistant at Styczynski...           0.205091
# 42       Lead Official at Western Illinois University           0.107945
# 43  Seeking employment opportunities within Custom...           0.323732
# 44  Admissions Representative at Community medical...           0.058395
# 45  Seeking Human  Resources Opportunities. Open t...           0.045842
# 46              Student at Westfield State University           0.075590
# 47  Student at Indiana University Kokomo - Busines...           0.224289
# 48              Aspiring Human Resources Professional           0.434607
# 49                                            Student           0.219431
# 50                   Seeking Human Resources Position           0.089255
# 51  Aspiring Human Resources Manager | Graduating ...           0.070603
# 52              Human Resources Generalist at Loparex           0.143408
# 53   Business Intelligence and Analytics at Travelers           0.137585
# 54                     Always set them up for Success          -0.049728
# 55   Director Of Administration at Excellence Logging           0.204272
#
#     job_title_char_count  job_title_word_count  job_title_avg_word_len  \
# 0                    104                    15                6.933333
# 1                     57                     9                6.333333
# 2                     37                     4                9.250000
# 3                     38                     5                7.600000
# 4                     47                     7                6.714286
# 5                     35                     4                8.750000
# 6                     65                     9                7.222222
# 7                     20                     3                6.666667
# 8                     53                     7                7.571429
# 9                     29                     4                7.250000
# 10                   107                    20                5.350000
# 11                    64                     7                9.142857
# 12                    37                     4                9.250000
# 13                    65                     8                8.125000
# 14                    37                     4                9.250000
# 15                    65                     9                7.222222
# 16                    53                     7                7.571429
# 17                    68                     8                8.500000
# 18                    53                     6                8.833333
# 19                    39                     5                7.800000
# 20                    58                     8                7.250000
# 21                    94                    13                7.230769
# 22                    47                     6                7.833333
# 23                    62                     8                7.750000
# 24                    72                     9                8.000000
# 25                    28                     3                9.333333
# 26                   100                    12                8.333333
# 27                   117                    16                7.312500
# 28                   101                    10               10.100000
# 29                    38                     5                7.600000
# 30                    53                     7                7.571429
# 31                    40                     5                8.000000
# 32                    61                     8                7.625000
# 33                    76                    10                7.600000
# 34                    41                     7                5.857143
# 35                    65                    10                6.500000
# 36                    66                     9                7.333333
# 37                    84                    12                7.000000
# 38                    69                    10                6.900000
# 39                    32                     4                8.000000
# 40                    31                     5                6.200000
# 41                    50                     6                8.333333
# 42                    44                     6                7.333333
# 43                    72                     9                8.000000
# 44                    64                     8                8.000000
# 45                    70                     9                7.777778
# 46                    37                     5                7.400000
# 47                   105                    16                6.562500
# 48                    37                     4                9.250000
# 49                     7                     1                7.000000
# 50                    32                     4                8.000000
# 51                   117                    18                6.500000
# 52                    37                     5                7.400000
# 53                    48                     6                8.000000
# 54                    30                     6                5.000000
# 55                    48                     6                8.000000
#
#     keyword_char_match  seniority_score  job_title_punct_penalty  \
# 0             0.269231             0.00                 0.019231
# 1             0.438596             0.00                 0.035088
# 2             0.756757             0.00                 0.000000
# 3             0.526316             0.00                 0.000000
# 4             0.531915             0.00                 0.000000
# 5             0.771429             0.60                 0.000000
# 6             0.415385             0.00                 0.000000
# 7             1.200000             0.75                 0.000000
# 8             0.509434             0.00                 0.000000
# 9             0.793103             0.00                 0.000000
# 10            0.261682             1.00                 0.000000
# 11            0.406250             0.90                 0.000000
# 12            0.756757             0.00                 0.000000
# 13            0.400000             0.05                 0.000000
# 14            0.702703             0.00                 0.000000
# 15            0.415385             0.00                 0.000000
# 16            0.509434             0.00                 0.000000
# 17            0.411765             0.70                 0.000000
# 18            0.528302             0.00                 0.000000
# 19            0.692308             0.60                 0.000000
# 20            0.465517             0.90                 0.000000
# 21            0.297872             0.70                 0.000000
# 22            0.553191             0.00                 0.000000
# 23            0.419355             0.70                 0.000000
# 24            0.361111             0.70                 0.000000
# 25            1.000000             0.00                 0.000000
# 26            0.280000             0.00                 0.040000
# 27            0.239316             0.00                 0.000000
# 28            0.277228             0.00                 0.000000
# 29            0.684211             0.00                 0.026316
# 30            0.509434             0.00                 0.000000
# 31            0.600000             0.20                 0.000000
# 32            0.442623             0.75                 0.000000
# 33            0.368421             0.80                 0.000000
# 34            0.585366             0.70                 0.000000
# 35            0.430769             0.80                 0.000000
# 36            0.333333             0.95                 0.030303
# 37            0.309524             0.60                 0.000000
# 38            0.391304             0.00                 0.000000
# 39            0.750000             0.00                 0.000000
# 40            0.806452             0.90                 0.000000
# 41            0.440000             0.00                 0.000000
# 42            0.568182             0.80                 0.000000
# 43            0.375000             0.00                 0.000000
# 44            0.421875             0.00                 0.000000
# 45            0.385714             0.00                 0.000000
# 46            0.567568             0.00                 0.000000
# 47            0.247619             0.70                 0.000000
# 48            0.756757             0.00                 0.000000
# 49            1.571429             0.00                 0.000000
# 50            0.812500             0.00                 0.000000
# 51            0.230769             0.70                 0.000000
# 52            0.729730             0.00                 0.000000
# 53            0.437500             0.00                 0.000000
# 54            0.833333             0.00                 0.000000
# 55            0.500000             0.90                 0.000000
#
#     similarity_cluster  word2vec_similarity  sentence_similarity  \
# 0                    0             0.452996             0.535285
# 1                    0             0.552295             0.253609
# 2                    1             0.861874             0.877541
# 3                    1             0.817421             0.606107
# 4                    0             0.687182             0.304957
# 5                    1             0.861874             0.837783
# 6                    0             0.552295             0.723124
# 7                    1             1.000000             0.602272
# 8                    0             0.687182             0.695969
# 9                    0             0.861874             0.434757
# 10                   2             0.676654             0.365815
# 11                   1             0.687182             0.672723
# 12                   1             0.861874             0.877541
# 13                   1             0.591165             0.653394
# 14                   0             0.861874             0.623115
# 15                   0             0.552295             0.723124
# 16                   0             0.687182             0.695969
# 17                   1             0.591165             0.635963
# 18                   1             0.752629             0.811570
# 19                   1             0.817421             0.595379
# 20                   1             0.591165             0.684035
# 21                   1             0.464629             0.607144
# 22                   2             0.752629             0.620953
# 23                   1             0.591165             0.711428
# 24                   1             0.696539             0.599120
# 25                   2             1.000000             1.000000
# 26                   1             0.478636             0.380546
# 27                   1             0.463288             0.645256
# 28                   0             0.667036             0.562171
# 29                   1             0.817421             0.637839
# 30                   1             0.687182             0.653053
# 31                   1             0.817421             0.399161
# 32                   2             0.591165             0.523558
# 33                   1             0.535582             0.796983
# 34                   1             0.687182             0.580486
# 35                   1             0.535582             0.630524
# 36                   1             0.552295            -0.048447
# 37                   1             0.608479             0.456410
# 38                   0             0.667060             0.430403
# 39                   1             0.861874             0.786355
# 40                   1             0.817421             0.503425
# 41                   0             0.752629             0.431265
# 42                   0             0.752629             0.290736
# 43                   1             0.552295             0.263235
# 44                   0             0.591165            -0.021075
# 45                   0             0.552295             0.296024
# 46                   0             0.817421             0.271887
# 47                   0             0.633602             0.217854
# 48                   1             0.861874             0.877541
# 49                   0             0.663140             0.258784
# 50                   0             0.861874             0.736675
# 51                   0             0.694293             0.647928
# 52                   0             0.817421             0.581286
# 53                   0             0.752629             0.124743
# 54                   0             0.752629             0.126065
# 55                   0             0.752629             0.319056
#
#     experience_score  Glove_similarity  connection_score  country_1  \
# 0                0.0          0.779651             0.170      False
# 1                0.0          0.698349             1.000      False
# 2                0.0          0.962704             0.088      False
# 3                0.0          0.759374             1.000      False
# 4                0.0          0.611781             1.000      False
# 5                0.0          0.941389             0.002      False
# 6                0.0          0.855249             0.122      False
# 7                0.0          0.631134             1.000      False
# 8                0.0          0.917740             1.000      False
# 9                0.0          0.603305             0.004      False
# 10               0.0          0.728717             1.000      False
# 11               0.0          0.750437             1.000      False
# 12               0.0          0.962704             0.088      False
# 13               0.0          0.904833             1.000      False
# 14               0.0          0.920633             0.780      False
# 15               0.0          0.855249             0.122      False
# 16               0.0          0.917740             1.000      False
# 17               1.0          0.907270             0.114      False
# 18               0.0          0.943054             1.000      False
# 19               0.0          0.861180             1.000      False
# 20               0.0          0.844917             1.000      False
# 21               0.0          0.820847             0.164      False
# 22               0.0          0.906996             1.000      False
# 23               0.0          0.903507             0.010      False
# 24               0.0          0.954329             0.014      False
# 25               0.0          1.000000             0.032      False
# 26               0.0          0.823870             1.000      False
# 27               0.0          0.911349             0.424      False
# 28               0.0          0.888824             0.818      False
# 29               0.0          0.870880             1.000      False
# 30               0.0          0.883090             0.014      False
# 31               0.0          0.745499             0.104      False
# 32               0.0          0.892666             0.910      False
# 33               0.0          0.907389             0.348      False
# 34               0.0          0.660362             0.536      False
# 35               0.0          0.910427             0.100      False
# 36               0.0          0.639865             1.000      False
# 37               0.0          0.853339             0.008      False
# 38               0.0          0.735428             0.080      False
# 39               0.0          0.928165             0.036      False
# 40               0.0          0.877698             0.698      False
# 41               0.0          0.701889             0.310      False
# 42               0.0          0.675843             0.078      False
# 43               0.0          0.805396             0.128      False
# 44               0.0          0.729183             0.018      False
# 45               0.0          0.856721             0.830       True
# 46               0.0          0.621249             0.114      False
# 47               0.0          0.676295             0.038      False
# 48               0.0          0.962704             0.142      False
# 49               0.0          0.633637             0.008      False
# 50               0.0          0.919796             0.096      False
# 51               0.0          0.877200             0.206      False
# 52               0.0          0.923735             1.000      False
# 53               0.0          0.727623             0.098      False
# 54               0.0          0.744818             1.000      False
# 55               0.0          0.844156             1.000      False
#
#     country_2  country_3  country_4
# 0       False      False       True
# 1        True      False      False
# 2       False      False       True
# 3       False      False       True
# 4       False       True      False
# 5       False      False       True
# 6        True      False      False
# 7       False      False       True
# 8       False      False       True
# 9       False      False       True
# 10      False      False       True
# 11      False      False       True
# 12      False      False       True
# 13      False      False       True
# 14      False      False       True
# 15       True      False      False
# 16      False      False       True
# 17      False      False       True
# 18      False      False       True
# 19      False      False       True
# 20      False      False       True
# 21      False      False       True
# 22      False      False       True
# 23      False      False       True
# 24      False      False       True
# 25      False      False       True
# 26      False      False       True
# 27      False      False       True
# 28      False      False       True
# 29      False      False       True
# 30      False      False       True
# 31      False      False       True
# 32      False      False       True
# 33      False      False       True
# 34      False      False       True
# 35      False      False       True
# 36      False      False       True
# 37      False      False       True
# 38      False      False       True
# 39      False      False       True
# 40      False      False       True
# 41      False      False       True
# 42      False      False       True
# 43      False      False       True
# 44      False      False       True
# 45      False      False      False
# 46      False      False       True
# 47      False      False       True
# 48      False      False       True
# 49      False      False       True
# 50      False      False       True
# 51      False      False       True
# 52      False      False       True
# 53      False      False       True
# 54      False      False       True
# 55      False      False       True

# %%
req_data = featured_data_encoded.drop(columns=['job_title'], axis=1)

# Select the features to use for ranking based on InitialRanker.feature_weights
features_for_ranking = req_data.columns

# Extract the relevant features from the dataframe
features_df = featured_data_encoded[features_for_ranking]

# Instantiate the ranker and get the ranked indices
ranker = InitialRanker()
ranked_indices, scores = ranker.rank_results(features_df)

# Add a 'rank' column to the dataframe based on the ranking
featured_data_encoded['rank'] = 0
featured_data_encoded.loc[ranked_indices, 'rank'] = range(1, len(featured_data_encoded) + 1)

featured_data_encoded['scaled_score'] = 0.0
featured_data_encoded.loc[ranked_indices, 'scaled_score'] = scores[ranked_indices]

# Display the top 20 ranked entries
featured_data_encoded.sort_values('rank').head(20)
# Out:
#                                             job_title  similarity_scores  \
# 10  SVP, CHRO, Marketing & Communications, CSR Off...           0.626174
# 27  Aspiring Human Resources Professional | Passio...           0.414139
# 17  Experienced Retail Manager and aspiring Human ...           0.462731
# 26  Nortia Staffing is seeking Human Resources, Pa...           0.362404
# 25                       Human Resources Professional           0.564406
# 28  Human Resources|\nConflict Management|\nPolici...           0.207744
# 21  Retired Army National Guard Recruiter, office ...           0.285704
# 37  Information Systems Specialist and Programmer ...           0.395373
# 51  Aspiring Human Resources Manager | Graduating ...           0.070603
# 2               Aspiring Human Resources Professional           0.434607
# 12              Aspiring Human Resources Professional           0.434607
# 47  Student at Indiana University Kokomo - Busines...           0.224289
# 24  Aspiring Human Resources Manager, seeking inte...           0.328378
# 48              Aspiring Human Resources Professional           0.434607
# 33  Aspiring Human Resources Professional | An ene...           0.334932
# 32  Senior Human Resources Business Partner at Hei...           0.497335
# 11  Human Resources Coordinator at InterContinenta...           0.258530
# 5                 Aspiring Human Resources Specialist           0.345871
# 35  Human Resources professional for the world lea...           0.433419
# 36  RRP Brand Portfolio Executive at JTI (Japan To...           0.385114
#
#     job_title_char_count  job_title_word_count  job_title_avg_word_len  \
# 10                   107                    20                5.350000
# 27                   117                    16                7.312500
# 17                    68                     8                8.500000
# 26                   100                    12                8.333333
# 25                    28                     3                9.333333
# 28                   101                    10               10.100000
# 21                    94                    13                7.230769
# 37                    84                    12                7.000000
# 51                   117                    18                6.500000
# 2                     37                     4                9.250000
# 12                    37                     4                9.250000
# 47                   105                    16                6.562500
# 24                    72                     9                8.000000
# 48                    37                     4                9.250000
# 33                    76                    10                7.600000
# 32                    61                     8                7.625000
# 11                    64                     7                9.142857
# 5                     35                     4                8.750000
# 35                    65                    10                6.500000
# 36                    66                     9                7.333333
#
#     keyword_char_match  seniority_score  job_title_punct_penalty  \
# 10            0.261682             1.00                 0.000000
# 27            0.239316             0.00                 0.000000
# 17            0.411765             0.70                 0.000000
# 26            0.280000             0.00                 0.040000
# 25            1.000000             0.00                 0.000000
# 28            0.277228             0.00                 0.000000
# 21            0.297872             0.70                 0.000000
# 37            0.309524             0.60                 0.000000
# 51            0.230769             0.70                 0.000000
# 2             0.756757             0.00                 0.000000
# 12            0.756757             0.00                 0.000000
# 47            0.247619             0.70                 0.000000
# 24            0.361111             0.70                 0.000000
# 48            0.756757             0.00                 0.000000
# 33            0.368421             0.80                 0.000000
# 32            0.442623             0.75                 0.000000
# 11            0.406250             0.90                 0.000000
# 5             0.771429             0.60                 0.000000
# 35            0.430769             0.80                 0.000000
# 36            0.333333             0.95                 0.030303
#
#     similarity_cluster  word2vec_similarity  sentence_similarity  \
# 10                   2             0.676654             0.365815
# 27                   1             0.463288             0.645256
# 17                   1             0.591165             0.635963
# 26                   1             0.478636             0.380546
# 25                   2             1.000000             1.000000
# 28                   0             0.667036             0.562171
# 21                   1             0.464629             0.607144
# 37                   1             0.608479             0.456410
# 51                   0             0.694293             0.647928
# 2                    1             0.861874             0.877541
# 12                   1             0.861874             0.877541
# 47                   0             0.633602             0.217854
# 24                   1             0.696539             0.599120
# 48                   1             0.861874             0.877541
# 33                   1             0.535582             0.796983
# 32                   2             0.591165             0.523558
# 11                   1             0.687182             0.672723
# 5                    1             0.861874             0.837783
# 35                   1             0.535582             0.630524
# 36                   1             0.552295            -0.048447
#
#     experience_score  Glove_similarity  connection_score  country_1  \
# 10               0.0          0.728717             1.000      False
# 27               0.0          0.911349             0.424      False
# 17               1.0          0.907270             0.114      False
# 26               0.0          0.823870             1.000      False
# 25               0.0          1.000000             0.032      False
# 28               0.0          0.888824             0.818      False
# 21               0.0          0.820847             0.164      False
# 37               0.0          0.853339             0.008      False
# 51               0.0          0.877200             0.206      False
# 2                0.0          0.962704             0.088      False
# 12               0.0          0.962704             0.088      False
# 47               0.0          0.676295             0.038      False
# 24               0.0          0.954329             0.014      False
# 48               0.0          0.962704             0.142      False
# 33               0.0          0.907389             0.348      False
# 32               0.0          0.892666             0.910      False
# 11               0.0          0.750437             1.000      False
# 5                0.0          0.941389             0.002      False
# 35               0.0          0.910427             0.100      False
# 36               0.0          0.639865             1.000      False
#
#     country_2  country_3  country_4  rank  scaled_score
# 10      False      False       True     1      1.000000
# 27      False      False       True     2      0.919348
# 17      False      False       True     3      0.904655
# 26      False      False       True     4      0.876543
# 25      False      False       True     5      0.862475
# 28      False      False       True     6      0.837426
# 21      False      False       True     7      0.760092
# 37      False      False       True     8      0.754135
# 51      False      False       True     9      0.752776
# 2       False      False       True    10      0.734130
# 12      False      False       True    11      0.734130
# 47      False      False       True    12      0.733553
# 24      False      False       True    13      0.732645
# 48      False      False       True    14      0.731934
# 33      False      False       True    15      0.727472
# 32      False      False       True    16      0.726752
# 11      False      False       True    17      0.696981
# 5       False      False       True    18      0.681411
# 35      False      False       True    19      0.666318
# 36      False      False       True    20      0.656256

# %%
req_data.head()
# Out:
#    similarity_scores  job_title_char_count  job_title_word_count  \
# 0           0.084313                   104                    15
# 1           0.138683                    57                     9
# 2           0.434607                    37                     4
# 3           0.369073                    38                     5
# 4           0.143914                    47                     7
#
#    job_title_avg_word_len  keyword_char_match  seniority_score  \
# 0                6.933333            0.269231              0.0
# 1                6.333333            0.438596              0.0
# 2                9.250000            0.756757              0.0
# 3                7.600000            0.526316              0.0
# 4                6.714286            0.531915              0.0
#
#    job_title_punct_penalty  similarity_cluster  word2vec_similarity  \
# 0                 0.019231                   0             0.452996
# 1                 0.035088                   0             0.552295
# 2                 0.000000                   1             0.861874
# 3                 0.000000                   1             0.817421
# 4                 0.000000                   0             0.687182
#
#    sentence_similarity  experience_score  Glove_similarity  connection_score  \
# 0             0.535285               0.0          0.779651             0.170
# 1             0.253609               0.0          0.698349             1.000
# 2             0.877541               0.0          0.962704             0.088
# 3             0.606107               0.0          0.759374             1.000
# 4             0.304957               0.0          0.611781             1.000
#
#    country_1  country_2  country_3  country_4
# 0      False      False      False       True
# 1      False       True      False      False
# 2      False      False      False       True
# 3      False      False      False       True
# 4      False      False       True      False

# %%
class ContextualBandit:
    def __init__(self, n_features, alpha=1.0):
        self.n_features = n_features
        self.alpha = alpha
        
        # Initialize parameters for each arm (ranking position)
        self.A = [np.eye(n_features) for _ in range(10)]  # Top 10 positions
        self.b = [np.zeros(n_features) for _ in range(10)]
        self.interaction_count = 0
    
    def select_item_for_position(self, candidates, position):
        """Select best item for a specific position using LinUCB"""
        scores = []
        
        for candidate in candidates:
            features = candidate['features']
            A_inv = np.linalg.inv(self.A[position])
            theta = A_inv @ self.b[position]
            
            # Confidence bound
            confidence = self.alpha * np.sqrt(features.T @ A_inv @ features)
            score = theta.T @ features + confidence
            scores.append(score)
        
        return np.argmax(scores)
    
    def update_position(self, position, features, reward):
        """Update parameters for a specific position"""
        self.A[position] += np.outer(features, features)
        self.b[position] += reward * features
        self.interaction_count += 1

# %%
class ColdStartRankingPipeline:
    def __init__(self, max_results=10):
        self.baseline_ranker = InitialRanker()
        self.bandit = ContextualBandit(n_features=8)  # Adjust based on features
        self.max_results = max_results
        self.exploration_rate = 0.3  # Start high, decay over time
        
    def rank_query_results(self, query_results):
        """Main ranking function"""
        # Extract features
        features = self._extract_features(query_results)
        
        # Get baseline ranking
        baseline_ranking = self.baseline_ranker.rank_results(features)
        
        # Decide exploration vs exploitation
        if self._should_explore():
            return self._explore_ranking(query_results, features)
        else:
            return self._exploit_ranking(query_results, features, baseline_ranking)
    
    def _should_explore(self):
        """Decay exploration over time"""
        decay_rate = 0.995
        current_rate = self.exploration_rate * (decay_rate ** self.bandit.interaction_count)
        return np.random.random() < current_rate
    
    def _explore_ranking(self, query_results, features):
        """Exploration: try different rankings"""
        n_results = min(len(query_results), self.max_results)
        
        # Random permutation with some bias toward similarity
        weights = features[:, 0]  # Cosine similarity column
        weights = np.exp(weights) / np.sum(np.exp(weights))  # Softmax
        
        ranking = np.random.choice(
            len(query_results), 
            size=n_results, 
            replace=False, 
            p=weights
        )
        return ranking
    
    def _exploit_ranking(self, query_results, features, baseline_ranking):
        """Exploitation: use learned preferences"""
        available_items = list(range(len(query_results)))
        final_ranking = []
        
        for position in range(min(self.max_results, len(query_results))):
            # Use bandit to select best item for this position
            candidates = [{'features': features[i], 'index': i} 
                         for i in available_items]
            
            selected_idx = self.bandit.select_item_for_position(candidates, position)
            item_index = available_items[selected_idx]
            
            final_ranking.append(item_index)
            available_items.remove(item_index)
        
        return np.array(final_ranking)

# %%
class FeedbackProcessor:
    def __init__(self, pipeline):
        self.pipeline = pipeline
        self.feedback_history = []
        
    def process_user_stars(self, query_results, ranking, starred_items):
        """Process user feedback and update models"""
        features = self.pipeline._extract_features(query_results)
        
        # Calculate rewards for each position
        for position, item_idx in enumerate(ranking):
            if position >= 10:  # Only track top 10
                break
                
            # Reward calculation
            reward = self._calculate_position_reward(item_idx, starred_items, position)
            
            # Update bandit for this position
            self.pipeline.bandit.update_position(
                position, 
                features[item_idx], 
                reward
            )
        
        # Store feedback for analysis
        self.feedback_history.append({
            'query': query_results,
            'ranking': ranking,
            'starred': starred_items,
            'timestamp': time.time()
        })
        
        # Periodically update baseline weights
        if len(self.feedback_history) % 50 == 0:
            self._update_baseline_weights()
    
    def _calculate_position_reward(self, item_idx, starred_items, position):
        """Calculate reward based on position and stars"""
        if item_idx in starred_items:
            # Higher reward for starred items at top positions
            return 1.0 / (position + 1)
        else:
            # Small negative reward for non-starred items at top
            return -0.1 / (position + 1)
    
    def _update_baseline_weights(self):
        """Update baseline feature weights based on feedback"""
        if len(self.feedback_history) < 10:
            return
        
        # Analyze which features correlate with starred items
        starred_features = []
        non_starred_features = []
        
        for feedback in self.feedback_history[-100:]:  # Last 100 interactions
            features = self.pipeline._extract_features(feedback['query'])
            
            for item_idx in feedback['starred']:
                starred_features.append(features[item_idx])
            
            for i, item in enumerate(feedback['query']):
                if i not in feedback['starred']:
                    non_starred_features.append(features[i])
        
        # Simple feature importance update
        if starred_features and non_starred_features:
            starred_mean = np.mean(starred_features, axis=0)
            non_starred_mean = np.mean(non_starred_features, axis=0)
            
            # Update weights based on feature differences
            feature_importance = np.abs(starred_mean - non_starred_mean)
            feature_importance = feature_importance / np.sum(feature_importance)
            
            feature_names = list(self.pipeline.baseline_ranker.feature_weights.keys())
            for i, feature in enumerate(feature_names):
                self.pipeline.baseline_ranker.feature_weights[feature] = feature_importance[i]

# %%
class RankingSystem:
    def __init__(self):
        self.pipeline = ColdStartRankingPipeline()
        self.feedback_processor = FeedbackProcessor(self.pipeline)
        self.query_count = 0
        
    def search_and_rank(self, query, job_titles):
        """Main search interface"""
        self.query_count += 1

        query_results = self._search_candidates(query, job_titles)

    def _search_candidates(self, query, job_titles):
        """Simple search implementation"""
        candidates = []
        query_words = set(query.lower().split())
        
        for i, job_title in enumerate(job_titles):
            title_words = set(job_title.lower().split())
            
            # Check if there's any overlap
            if query_words.intersection(title_words):
                candidates.append({
                    'title': job_title,
                    'text': job_title,
                    'original_index': i
                })
        
        return candidates
        
        # Rank results
        ranking = self.pipeline.rank_query_results(query_results)
        
        # Return ranked results
        return [query_results[i] for i in ranking]
    
    def process_user_feedback(self, query_results, ranking, starred_items):
        """Handle user stars"""
        self.feedback_processor.process_user_stars(
            query_results, ranking, starred_items
        )
        
    def get_system_stats(self):
        """Return system performance metrics"""
        return {
            'total_queries': self.query_count,
            'interactions': self.pipeline.bandit.interaction_count,
            'current_exploration_rate': self.pipeline.exploration_rate * 
                (0.995 ** self.pipeline.bandit.interaction_count),
            'feedback_count': len(self.feedback_processor.feedback_history)
        }

# %%
# Initialize system
ranking_system = RankingSystem()

# Search and rank
results = ranking_system.search_and_rank("python developer", job_titles)

# User stars some results
starred_indices = [0, 2]  # User starred 1st and 3rd results
ranking_system.process_user_feedback(results, list(range(len(results))), starred_indices)

# System learns and improves over time
